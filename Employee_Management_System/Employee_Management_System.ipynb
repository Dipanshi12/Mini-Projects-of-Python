# %%
Employees_List = {}
def add_employee():
    Name = input("Enter name of the employee:")
    Salary = int(input("Enter salary of the employee:"))
    Employees_List[Name] = Salary
def search_employee():
    Name = input("Enter name of the employee to search:")
    if Name in Employees_List:
        Employees_List[Name]
        print(f"Employee name is :{Name} and salary is:{Employees_List[Name]}")
    else:
        print("name is not in the list")
def salary():
     Name = input("Enter name of the employee:")
     if Name in Employees_List:
        Updated_Salary = int(input("Enter salary of the employee:"))
        Employees_List[Name] = Updated_Salary 
        print("Salary is updated")
     else:
        print("No updation")
def delete():
    Name = input("Enter name of the employee to delete:")
    if Name in Employees_List:
      del Employees_List[Name]
      print(f"{Name} is deleted")
    else:
      print("not deleted")
def display():
    for Name,Salary in Employees_List.items():
        print(f"{Name} : {Salary} ")
def Employees_Management_System():
 print("\n-----Employees_Management_System-----")
 print("1.add employee")
 print("2.search employee")
 print("3.salary updation")
 print("4.delete employee")
 print("5.display employee")
 print("Exit")
while True:
       
        choice = int(input("Enter your choice:"))
        if choice == 1:
            add_employee()
        elif choice == 2:
            search_employee()
        elif choice == 3:
            salary()
        elif choice == 4:
            delete()
        elif choice == 5:
            display()
        elif choice == 6:
            print("Thanks!")
            break
        else:
            print("invalid")
            
Employees_Management_System()
# Out:
# Enter your choice: 1
# Enter name of the employee: roy
# Enter salary of the employee: 4500
# Enter your choice: 1
# Enter name of the employee: tim
# Enter salary of the employee: 6700
# Enter your choice: 1
# Enter name of the employee: will
# Enter salary of the employee: 5600
# Enter your choice: 5
# roy : 4500
# tim : 6700
# will : 5600
# Enter your choice: 2
# Enter name of the employee to search: tim
# Employee name is :tim and salary is:6700
# Enter your choice: 3
# Enter name of the employee: tim
# Enter salary of the employee: 5000
# Salary is updated
# Enter your choice: 5
# roy : 4500
# tim : 5000
# will : 5600
# Enter your choice: 4
# Enter name of the employee to delete: tim
# tim is deleted
# Enter your choice: 7
# invalid
# Enter your choice: 8
# invalid
# Enter your choice: 6
# Thanks!
#
# -----Employees_Management_System-----
# 1.add employee
# 2.search employee
# 3.salary updation
# 4.delete employee
# 5.display employee
# Exit
