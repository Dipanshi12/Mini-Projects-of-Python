# %%
#Contact_Book
contacts = {}
#Adding contact
def add_contact():
    number = int(input("Enter contact:"))
    name = input("Enter name:")
    contacts[name] = number
#Displaying contact
def display():
    for name,number in contacts.items():
        print(f"{name} : {number}")
#Searching contact
def search():
    name = input("enter name for search")
    if name in contacts:
        contacts[name]
        print("contact found",contacts[name])
    else:
        print("contact not found")
#Deleting contact
def delete():
    name = input("enter name to delete")
    if name in contacts:
     del contacts[name]
     print(f"{name} deleted successfully")
    else:
     print("contact not found")
#Menu
def contact_book():
 while True:
     print("\n-----Contact Book-----")
     print("1.Add contact")
     print("2.Display contact")
     print("3.Search contact")
     print("4.Delete contact")
     print("5.Exit")
     id = int(input("Enter operation you want to perform with its id:"))
     if id == 1:
         add_contact()
     elif id == 2:
         display()
     elif id == 3:
         search()
     elif id == 4:
         delete()
     elif id == 5:
      print("Thanks!")
      break
     else:
      print("invalid operation")
#Calling function
contact_book()
# Out:
# -----Contact Book-----
# 1.Add contact
# 2.Display contact
# 3.Search contact
# 4.Delete contact
# 5.Exit
# Enter operation you want to perform with its id: 1
# Enter contact: 876
# Enter name: Tim
# -----Contact Book-----
# 1.Add contact
# 2.Display contact
# 3.Search contact
# 4.Delete contact
# 5.Exit
# Enter operation you want to perform with its id: 1
# Enter contact: 904
# Enter name: Roy
# -----Contact Book-----
# 1.Add contact
# 2.Display contact
# 3.Search contact
# 4.Delete contact
# 5.Exit
# Enter operation you want to perform with its id: 1
# Enter contact: 56
# Enter name: Will
# -----Contact Book-----
# 1.Add contact
# 2.Display contact
# 3.Search contact
# 4.Delete contact
# 5.Exit
# Enter operation you want to perform with its id: 2
# Tim : 876
# Roy : 904
# Will : 56
#
# -----Contact Book-----
# 1.Add contact
# 2.Display contact
# 3.Search contact
# 4.Delete contact
# 5.Exit
# Enter operation you want to perform with its id: 3
# enter name for search Will
# contact found 56
#
# -----Contact Book-----
# 1.Add contact
# 2.Display contact
# 3.Search contact
# 4.Delete contact
# 5.Exit
# Enter operation you want to perform with its id: 4
# enter name to delete Will
# Will deleted successfully
#
# -----Contact Book-----
# 1.Add contact
# 2.Display contact
# 3.Search contact
# 4.Delete contact
# 5.Exit
# Enter operation you want to perform with its id: 2
# Tim : 876
# Roy : 904
#
# -----Contact Book-----
# 1.Add contact
# 2.Display contact
# 3.Search contact
# 4.Delete contact
# 5.Exit
# Enter operation you want to perform with its id: 5
# Thanks!
